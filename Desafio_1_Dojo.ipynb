# %% [markdown]
# Olá! Este é o desafio relativo ao Primeiro Contato com o Google Colab.
#
# Aqui você poderá pôr em prática os seus conhecimentos recém adquiridos. Use as células abaixo para realizar as tarefas propostas.

# %% [markdown]
# # Tarefa 1
#
# "monte o seu drive"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Tarefa 2
#
# Procure um Dataset que voce tenha interesse no Kaggle. Se tiver dificuldade escolha um dos abaixo:
#
# - https://www.kaggle.com/datasets/alphiree/cardiovascular-diseases-risk-prediction-dataset
# - https://www.kaggle.com/datasets/arnavsmayan/netflix-userbase-dataset
# - https://www.kaggle.com/datasets/nelgiriyewithana/countries-of-the-world-2023

# %% [markdown]
# # Tarefa 3
#
# importe o seu Dataset

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DOJO - Hype/CVD_cleaned.csv')

# %% [markdown]
# # Tarefa 4
#
# obtenha algumas medidas desse Dataframe

# %%
df.head()
# Out:
#   General_Health                  Checkup Exercise Heart_Disease Skin_Cancer  \
# 0           Poor  Within the past 2 years       No            No          No
# 1      Very Good     Within the past year       No           Yes          No
# 2      Very Good     Within the past year      Yes            No          No
# 3           Poor     Within the past year      Yes           Yes          No
# 4           Good     Within the past year       No            No          No
#
#   Other_Cancer Depression Diabetes Arthritis     Sex Age_Category  \
# 0           No         No       No       Yes  Female        70-74
# 1           No         No      Yes        No  Female        70-74
# 2           No         No      Yes        No  Female        60-64
# 3           No         No      Yes        No    Male        75-79
# 4           No         No       No        No    Male          80+
#
#    Height_(cm)  Weight_(kg)    BMI Smoking_History  Alcohol_Consumption  \
# ...

# %%
df.tail()
# Out:
#        General_Health                  Checkup Exercise Heart_Disease  \
# 308849      Very Good     Within the past year      Yes            No
# 308850           Fair  Within the past 5 years      Yes            No
# 308851      Very Good      5 or more years ago      Yes            No
# 308852      Very Good     Within the past year      Yes            No
# 308853      Excellent     Within the past year      Yes            No
#
#        Skin_Cancer Other_Cancer Depression  \
# 308849          No           No         No
# 308850          No           No         No
# 308851          No           No        Yes
# 308852          No           No         No
# 308853          No           No         No
#
#                                           Diabetes Arthritis     Sex  \
# 308849                                          No        No    Male
# 308850                                         Yes        No    Male
# 308851  Yes, but female told only during pregnancy        No  Female
# ...

# %%
df.shape
# Out:
# (308854, 19)

# %%
df.describe()
# Out:
#          Height_(cm)    Weight_(kg)            BMI  Alcohol_Consumption  \
# count  308854.000000  308854.000000  308854.000000        308854.000000
# mean      170.615249      83.588655      28.626211             5.096366
# std        10.658026      21.343210       6.522323             8.199763
# min        91.000000      24.950000      12.020000             0.000000
# 25%       163.000000      68.040000      24.210000             0.000000
# 50%       170.000000      81.650000      27.440000             1.000000
# 75%       178.000000      95.250000      31.850000             6.000000
# max       241.000000     293.020000      99.330000            30.000000
#
#        Fruit_Consumption  Green_Vegetables_Consumption  \
# count      308854.000000                 308854.000000
# mean           29.835200                     15.110441
# std            24.875735                     14.926238
# min             0.000000                      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308854 entries, 0 to 308853
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   General_Health                308854 non-null  object
#  1   Checkup                       308854 non-null  object
#  2   Exercise                      308854 non-null  object
#  3   Heart_Disease                 308854 non-null  object
#  4   Skin_Cancer                   308854 non-null  object
#  5   Other_Cancer                  308854 non-null  object
#  6   Depression                    308854 non-null  object
#  7   Diabetes                      308854 non-null  object
#  8   Arthritis                     308854 non-null  object
#  9   Sex                           308854 non-null  object
#  10  Age_Category                  308854 non-null  object
#  11  Height_(cm)                   308854 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['General_Health', 'Checkup', 'Exercise', 'Heart_Disease', 'Skin_Cancer',
#        'Other_Cancer', 'Depression', 'Diabetes', 'Arthritis', 'Sex',
#        'Age_Category', 'Height_(cm)', 'Weight_(kg)', 'BMI', 'Smoking_History',
#        'Alcohol_Consumption', 'Fruit_Consumption',
#        'Green_Vegetables_Consumption', 'FriedPotato_Consumption'],
#       dtype='object')

# %% [markdown]
# # Tarefa 5
#
# examine o Dataframe, trate valores nulos e linhas duplicadas.

# %%
df_sem_nan = df.dropna()
df_sem_nan.shape
# Out:
# (308854, 19)

# %%
df.duplicated().sum()
df_sem_duplicada = df.drop_duplicates()
df_sem_duplicada.shape
# Out:
# (308774, 19)

# %%
df_clean = df.dropna().drop_duplicates()
df_clean.shape
# Out:
# (308774, 19)

# %%
df_clean.head()
# Out:
#   General_Health                  Checkup Exercise Heart_Disease Skin_Cancer  \
# 0           Poor  Within the past 2 years       No            No          No
# 1      Very Good     Within the past year       No           Yes          No
# 2      Very Good     Within the past year      Yes            No          No
# 3           Poor     Within the past year      Yes           Yes          No
# 4           Good     Within the past year       No            No          No
#
#   Other_Cancer Depression Diabetes Arthritis     Sex Age_Category  \
# 0           No         No       No       Yes  Female        70-74
# 1           No         No      Yes        No  Female        70-74
# 2           No         No      Yes        No  Female        60-64
# 3           No         No      Yes        No    Male        75-79
# 4           No         No       No        No    Male          80+
#
#    Height_(cm)  Weight_(kg)    BMI Smoking_History  Alcohol_Consumption  \
# ...

# %% [markdown]
# # Tarefa 6
#
# Extraia algumas colunas (Series) do Dataframe

# %%
df_consumos = df[['Alcohol_Consumption','Fruit_Consumption','Green_Vegetables_Consumption','FriedPotato_Consumption']]
df_consumos.head()
# Out:
#    Alcohol_Consumption  Fruit_Consumption  Green_Vegetables_Consumption  \
# 0                  0.0               30.0                          16.0
# 1                  0.0               30.0                           0.0
# 2                  4.0               12.0                           3.0
# 3                  0.0               30.0                          30.0
# 4                  0.0                8.0                           4.0
#
#    FriedPotato_Consumption
# 0                     12.0
# 1                      4.0
# 2                     16.0
# 3                      8.0
# 4                      0.0

# %%
df_batatafrita = df['FriedPotato_Consumption']

# %% [markdown]
# # Tarefa 7
#
# Obtenha algumas medidas dessas colunas (Series)

# %%
top_10 = df.iloc[0:10]
top_10.sort_values('Height_(cm)', ascending = False)
# Out:
#   General_Health                  Checkup Exercise Heart_Disease Skin_Cancer  \
# 4           Good     Within the past year       No            No          No
# 5           Good     Within the past year       No            No          No
# 3           Poor     Within the past year      Yes           Yes          No
# 6           Fair     Within the past year      Yes           Yes          No
# 7           Good     Within the past year      Yes            No          No
# 1      Very Good     Within the past year       No           Yes          No
# 8           Fair     Within the past year       No            No          No
# 2      Very Good     Within the past year      Yes            No          No
# 9           Fair     Within the past year       No            No          No
# 0           Poor  Within the past 2 years       No            No          No
#
#   Other_Cancer Depression Diabetes Arthritis     Sex Age_Category  \
# ...

# %% [markdown]
# # Tarefa 8
#
# Extraia linhas de um dataset baseado no valor de uma variável específica

# %%
df_mais_160 = df[df['Height_(cm)'] > 160.0]
df_mais_160.sort_values('Height_(cm)', ascending = False)
# Out:
#        General_Health                  Checkup Exercise Heart_Disease  \
# 250651      Very Good     Within the past year      Yes            No
# 21193            Poor     Within the past year      Yes            No
# 257764           Good  Within the past 2 years       No            No
# 5297        Very Good     Within the past year      Yes            No
# 31694            Good     Within the past year      Yes            No
# ...               ...                      ...      ...           ...
# 293075      Very Good     Within the past year       No            No
# 62319       Excellent     Within the past year      Yes            No
# 265884           Good  Within the past 2 years      Yes            No
# 72596       Very Good     Within the past year       No            No
# 70555            Fair     Within the past year      Yes            No
#
#        Skin_Cancer Other_Cancer Depression Diabetes Arthritis     Sex  \
# ...

# %% [markdown]
# # Tarefa 8
#
# Realize um agrupamento de uma coluna com a função groupby()

# %%
df.groupby('Age_Category')['Height_(cm)'].mean()
# Out:
# Age_Category
# 18-24    172.503078
# 25-29    172.111914
# 30-34    171.794389
# 35-39    171.708871
# 40-44    171.637416
# 45-49    171.425744
# 50-54    171.249592
# 55-59    170.968810
# 60-64    170.699210
# 65-69    170.305467
# 70-74    169.412790
# 75-79    168.593770
# 80+      166.990032
# Name: Height_(cm), dtype: float64

# %%
df.groupby('Age_Category')['Fruit_Consumption'].mean()
# Out:
# Age_Category
# 18-24    26.669664
# 25-29    27.031561
# 30-34    28.824615
# 35-39    30.419684
# 40-44    30.486779
# 45-49    29.496423
# 50-54    29.263777
# 55-59    29.413809
# 60-64    29.983713
# 65-69    30.710534
# 70-74    30.314343
# 75-79    31.251920
# 80+      32.081766
# Name: Fruit_Consumption, dtype: float64
